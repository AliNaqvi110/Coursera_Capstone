# %% [markdown]
# ## Program For Photographers Event

# %% [markdown]
# ### Introduction

# %% [markdown]
# ABC is a company based in Toronto for organizing events, currently it works on a project to organize an event for 5 days for a group of photographers from all over the world.The company has to put a good program, including a hotel of residence, a hall for meetings, places of landscape to visit, stores for shopping, restaurants and cafes. So the company’s purpose is to make a list of places of landscape in Toronto, including the nearest restaurants, cafes, and shopping stores for each place.

# %% [markdown]
# ### Data Description

# %% [markdown]
# The data used in this project is provided by Foursquare location data. The data are grouped by landscape area, and each area included the information about this area and all information about restaurants, cafes, and stores which in this area.

# %% [markdown]
# ### Table of contents

# %% [markdown]
# ##### 01- Import Libraries <br>
# ##### 02- Define Foursquare Credentials <br>
# ##### 03- Define the city and get its latitude & longitude <br>
# ##### 04- Search for Hotels & clean dataframe <br>
# ##### 05- Search for Parks & clean dataframe <br>
# ##### 06- Search for Restaurants & clean dataframe <br>
# ##### 07- Search for Cafeteria & clean dataframe <br>
# ##### 08- Search for Shopping Stores & clean dataframe <br>
# ##### 09- Generate map to visualize hotels, shopping stores and Cafeteria and how they cluster together <br>
# ##### 10- Generate map to visualize Park, Restaurant and Cafeteria and how they cluster together

# %% [markdown]
# ### Import Libraries

# %%
import requests # to handle requests
import pandas as pd # for data analsysis
import numpy as np # to handle data in a vectorized manner

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
#tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.12
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     scikit-learn-0.20.1        |   py36h22eb022_0         5.7 MB
#     liblapack-3.8.0            |      11_openblas          10 KB  conda-forge
#     scipy-1.3.2                |   py36h921218d_0        18.0 MB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     libopenblas-0.3.6          |       h5a2b251_2         7.7 MB
#     liblapacke-3.8.0           |      11_openblas          10 KB  conda-forge
#     numpy-1.17.3               |   py36h95a1406_0         5.2 MB  conda-forge
#     libcblas-3.8.0             |      11_openblas          10 KB  conda-forge
#     libblas-3.8.0              |      11_openblas          10 KB  conda-forge
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     blas-2.11                  |         openblas          10 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        36.8 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.50-py_0                              conda-forge
#     geopy:         1.20.0-py_0                            conda-forge
#     libblas:       3.8.0-11_openblas                      conda-forge
#     libcblas:      3.8.0-11_openblas                      conda-forge
#     liblapack:     3.8.0-11_openblas                      conda-forge
#     liblapacke:    3.8.0-11_openblas                      conda-forge
#     libopenblas:   0.3.6-h5a2b251_2
#
# The following packages will be UPDATED:
#
#     blas:          1.1-openblas                           conda-forge --> 2.11-openblas         conda-forge
#     numpy:         1.16.2-py36_blas_openblash1522bff_0    conda-forge [blas_openblas] --> 1.17.3-py36h95a1406_0 conda-forge
#     scipy:         1.2.1-py36_blas_openblash1522bff_0     conda-forge [blas_openblas] --> 1.3.2-py36h921218d_0  conda-forge
#
# The following packages will be DOWNGRADED:
#
#     scikit-learn:  0.20.1-py36_blas_openblashebff5e3_1200 conda-forge [blas_openblas] --> 0.20.1-py36h22eb022_0
#
#
# Downloading and Extracting Packages
# scikit-learn-0.20.1  | 5.7 MB    | ##################################### | 100%
# liblapack-3.8.0      | 10 KB     | ##################################### | 100%
# scipy-1.3.2          | 18.0 MB   | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# libopenblas-0.3.6    | 7.7 MB    | ##################################### | 100%
# liblapacke-3.8.0     | 10 KB     | ##################################### | 100%
# numpy-1.17.3         | 5.2 MB    | ##################################### | 100%
# libcblas-3.8.0       | 10 KB     | ##################################### | 100%
# libblas-3.8.0        | 10 KB     | ##################################### | 100%
# geopy-1.20.0         | 57 KB     | ##################################### | 100%
# blas-2.11            | 10 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.12
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.

# %% [markdown]
# ### Define Foursquare Credentials

# %%
ClIENT_ID = 'N45O4RRDNKFDENDC3JZ0V40MDEAT3VIAHNND5JEIOHF4UXDY' #  Foursquare ID
ClIENT_SECRET = 'LHTZHTCDSJVJY52N2AELBKK3M401Q1KLQBPAB12KIPAMBOOU' # Foursquare Secret
VERSION = '20180604'
LIMIT =30
print('Your credentails:')
print('Foursquare_ID: ' + ClIENT_ID)
print('Foursquare_Secret:' + ClIENT_SECRET)
# Out:
# Your credentails:
# Foursquare_ID: N45O4RRDNKFDENDC3JZ0V40MDEAT3VIAHNND5JEIOHF4UXDY
# Foursquare_Secret:LHTZHTCDSJVJY52N2AELBKK3M401Q1KLQBPAB12KIPAMBOOU

# %% [markdown]
# ### Define the city and get its latitude & longitude

# %%
# define the city and get its latitude & longitude 
city = 'Toronto'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(city)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.653963 -79.387207

# %% [markdown]
# ### Search for Hotels

# %%
# search for hotels
search_query = 'Hotel'
radius = 500

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=N45O4RRDNKFDENDC3JZ0V40MDEAT3VIAHNND5JEIOHF4UXDY&client_secret=LHTZHTCDSJVJY52N2AELBKK3M401Q1KLQBPAB12KIPAMBOOU&ll=43.653963,-79.387207&v=20180604&query=Hotel&radius=500&limit=30'

# %%
# Send the GET Request and examine the results
results = requests.get(url).json()
#results

# %%
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                          id                                            name  \
# 0  4ab2d511f964a5209b6c20e3                   Sheraton Centre Toronto Hotel
# 1  4b68aed1f964a520de862be3                  The Rex Hotel Jazz & Blues Bar
# 2  52ce14b0498e50457ce11780     DoubleTree by Hilton Hotel Toronto Downtown
# 3  4f343a31e4b0230a3b337a90                                  VFM Test Hotel
# 4  5545d07e498e2facac03f666  Sheraton Centre Toronto Hotel - Grand Ballroom
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1574475889    False
# 1  [{'id': '4bf58dd8d48988d1e7931735', 'name': 'J...  v-1574475889    False
# 2  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1574475889    False
# 3  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1574475889    False
# 4  [{'id': '56aa371be4b08b9a8d5734cf', 'name': 'B...  v-1574475889    False
#
#         location.address location.crossStreet  location.lat  location.lng  \
# 0  123 Queen Street West          at York St.     43.651144    -79.384329
# 1         194 Queen St W  Queen & St. Patrick     43.650505    -79.388577
# 2    108 Chestnut Street          Dundas St W     43.654608    -79.385942
# 3         123 Test Drive      at somewhere St     43.658434    -79.387894
# 4  123 Queen Street West        at Bay Street     43.651200    -79.384520
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 43.6511441, 'lng'...                390
# 1  [{'label': 'display', 'lat': 43.65050475544005...                400
# 2  [{'label': 'display', 'lat': 43.6546083, 'lng'...                124
# 3  [{'label': 'display', 'lat': 43.658434, 'lng':...                500
# 4  [{'label': 'display', 'lat': 43.65119976208405...                376
#
#   location.postalCode location.cc location.city location.state  \
# 0             M5H 2M9          CA       Toronto             ON
# 1             M5V 1Z1          CA       Toronto             ON
# 2             M5G 1R3          CA       Toronto             ON
# 3             M2M 2M2          CA       Toronto             ON
# 4                 NaN          CA       Toronto             ON
#
#   location.country                          location.formattedAddress  \
# 0           Canada  [123 Queen Street West (at York St.), Toronto ...
# 1           Canada  [194 Queen St W (Queen & St. Patrick), Toronto...
# 2           Canada  [108 Chestnut Street (Dundas St W), Toronto ON...
# 3           Canada  [123 Test Drive (at somewhere St), Toronto ON ...
# 4           Canada  [123 Queen Street West (at Bay Street), Toront...
#
#   venuePage.id location.neighborhood
# 0          NaN                   NaN
# 1     62225795                   NaN
# 2          NaN                   NaN
# 3          NaN                   NaN
# 4          NaN    Financial District

# %% [markdown]
# ### Clean Hotel Dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
clean_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')]+ ['id']
clean_dataframe = dataframe.loc[:,clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
clean_dataframe['categories'] = clean_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_dataframe.columns = [column.split('.')[-1] for column in clean_dataframe.columns]

clean_dataframe.head()
# Out:
#                                              name categories  \
# 0                   Sheraton Centre Toronto Hotel      Hotel
# 1                  The Rex Hotel Jazz & Blues Bar  Jazz Club
# 2     DoubleTree by Hilton Hotel Toronto Downtown      Hotel
# 3                                  VFM Test Hotel      Hotel
# 4  Sheraton Centre Toronto Hotel - Grand Ballroom   Ballroom
#
#                  address          crossStreet        lat        lng  \
# 0  123 Queen Street West          at York St.  43.651144 -79.384329
# 1         194 Queen St W  Queen & St. Patrick  43.650505 -79.388577
# 2    108 Chestnut Street          Dundas St W  43.654608 -79.385942
# 3         123 Test Drive      at somewhere St  43.658434 -79.387894
# 4  123 Queen Street West        at Bay Street  43.651200 -79.384520
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 43.6511441, 'lng'...       390    M5H 2M9  CA
# 1  [{'label': 'display', 'lat': 43.65050475544005...       400    M5V 1Z1  CA
# 2  [{'label': 'display', 'lat': 43.6546083, 'lng'...       124    M5G 1R3  CA
# 3  [{'label': 'display', 'lat': 43.658434, 'lng':...       500    M2M 2M2  CA
# 4  [{'label': 'display', 'lat': 43.65119976208405...       376        NaN  CA
#
#       city state country                                   formattedAddress  \
# 0  Toronto    ON  Canada  [123 Queen Street West (at York St.), Toronto ...
# 1  Toronto    ON  Canada  [194 Queen St W (Queen & St. Patrick), Toronto...
# 2  Toronto    ON  Canada  [108 Chestnut Street (Dundas St W), Toronto ON...
# 3  Toronto    ON  Canada  [123 Test Drive (at somewhere St), Toronto ON ...
# 4  Toronto    ON  Canada  [123 Queen Street West (at Bay Street), Toront...
#
#          neighborhood                        id
# 0                 NaN  4ab2d511f964a5209b6c20e3
# 1                 NaN  4b68aed1f964a520de862be3
# 2                 NaN  52ce14b0498e50457ce11780
# 3                 NaN  4f343a31e4b0230a3b337a90
# 4  Financial District  5545d07e498e2facac03f666

# %%
# delete unnecessary columns
clean_dataframe2= clean_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs','neighborhood', 'id'], axis=1)
clean_dataframe2
# Out:
#                                               name              categories  \
# 0                    Sheraton Centre Toronto Hotel                   Hotel
# 1                   The Rex Hotel Jazz & Blues Bar               Jazz Club
# 2      DoubleTree by Hilton Hotel Toronto Downtown                   Hotel
# 3                                   VFM Test Hotel                   Hotel
# 4   Sheraton Centre Toronto Hotel - Grand Ballroom                Ballroom
# 5                                  Stathcona Hotel                   Hotel
# 6    hilton hotel, richmondstreet E, 145,  toronto              Hotel Pool
# 7                Sheraton Centre Hotel Club Lounge                  Lounge
# 8                                        650 Hotel                   Hotel
# 9                                Be SixFifty Hotel                   Hotel
# 10                              Shangri-La Toronto                   Hotel
# 11    Marriott Downtown at CF Toronto Eaton Centre                   Hotel
# 12                                  Hilton Toronto                   Hotel
# 13                           89 Chestnut Residence  College Residence Hall
# 14                   Op mijn hotelkamer In Toronto                   Hotel
# 15          Lobby Lounge at the Shangri-La Toronto                  Lounge
# 16                                  Fitness Centre                     Gym
# 17                                  Grand Ballroom             Event Space
# 18                                            Pool                    Pool
# 19                                   Kumar For Men             Men's Store
# 20                                   Bistro on Two          Breakfast Spot
# 21                                  Fitness Centre                     Gym
#
#                   address        lat        lng postalCode    state
# 0   123 Queen Street West  43.651144 -79.384329    M5H 2M9       ON
# 1          194 Queen St W  43.650505 -79.388577    M5V 1Z1       ON
# 2     108 Chestnut Street  43.654608 -79.385942    M5G 1R3       ON
# 3          123 Test Drive  43.658434 -79.387894    M2M 2M2       ON
# 4   123 Queen Street West  43.651200 -79.384520        NaN       ON
# 5                     NaN  43.654947 -79.386359        NaN       ON
# 6   Richmondstreet E, 145  43.650625 -79.385488        NaN       ON
# 7                     NaN  43.651063 -79.384527    M5H 2M9       ON
# 8          650 Bay Street  43.657046 -79.384411        NaN       ON
# 9          650 Bay Street  43.657120 -79.384560        NaN       ON
# 10    188 University Ave.  43.649129 -79.386557    M5H 0A3       ON
# 11         525 Bay Street  43.654728 -79.382422    M5G 2L2       ON
# 12      145 Richmond St W  43.649946 -79.385479    M5H 2L2       ON
# 13        89 Chestnut St.  43.654160 -79.385291    M5G 1R1       ON
# 14                    NaN  43.654235 -79.386208        NaN       ON
# 15    188 University Ave.  43.649155 -79.386546    M5H 0A3       ON
# 16            525 Bay St.  43.654690 -79.381739    M5G 2L2       ON
# 17        123 Queen St. W  43.651217 -79.383771    M5H 2M9       ON
# 18       Intercontinental  43.650975 -79.384053        NaN  Ontario
# 19        Sheraton Centre  43.651044 -79.383302    M5H 2M9       ON
# 20        123 Queen St. W  43.651011 -79.383658    M5H 2M9       ON
# 21        Sheraton Centre  43.650985 -79.384002    M5H 2M9       ON

# %%
# delete rows with none values
clean_dataframe3 = clean_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_dataframe3
# Out:
#                                             name              categories  \
# 0                  Sheraton Centre Toronto Hotel                   Hotel
# 1                 The Rex Hotel Jazz & Blues Bar               Jazz Club
# 2    DoubleTree by Hilton Hotel Toronto Downtown                   Hotel
# 3                                 VFM Test Hotel                   Hotel
# 10                            Shangri-La Toronto                   Hotel
# 11  Marriott Downtown at CF Toronto Eaton Centre                   Hotel
# 12                                Hilton Toronto                   Hotel
# 13                         89 Chestnut Residence  College Residence Hall
# 15        Lobby Lounge at the Shangri-La Toronto                  Lounge
# 16                                Fitness Centre                     Gym
# 17                                Grand Ballroom             Event Space
# 19                                 Kumar For Men             Men's Store
# 20                                 Bistro on Two          Breakfast Spot
# 21                                Fitness Centre                     Gym
#
#                   address        lat        lng postalCode state
# 0   123 Queen Street West  43.651144 -79.384329    M5H 2M9    ON
# 1          194 Queen St W  43.650505 -79.388577    M5V 1Z1    ON
# 2     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 3          123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 10    188 University Ave.  43.649129 -79.386557    M5H 0A3    ON
# 11         525 Bay Street  43.654728 -79.382422    M5G 2L2    ON
# 12      145 Richmond St W  43.649946 -79.385479    M5H 2L2    ON
# 13        89 Chestnut St.  43.654160 -79.385291    M5G 1R1    ON
# 15    188 University Ave.  43.649155 -79.386546    M5H 0A3    ON
# 16            525 Bay St.  43.654690 -79.381739    M5G 2L2    ON
# 17        123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON
# 19        Sheraton Centre  43.651044 -79.383302    M5H 2M9    ON
# 20        123 Queen St. W  43.651011 -79.383658    M5H 2M9    ON
# 21        Sheraton Centre  43.650985 -79.384002    M5H 2M9    ON

# %%
# delete rows which its category is not Hotel or Event Space
array= ['Hotel', 'Event Space']
hotel_dataframe= clean_dataframe3.loc[clean_dataframe3['categories'].isin(array)]
hotel_dataframe
# Out:
#                                             name   categories  \
# 0                  Sheraton Centre Toronto Hotel        Hotel
# 2    DoubleTree by Hilton Hotel Toronto Downtown        Hotel
# 3                                 VFM Test Hotel        Hotel
# 10                            Shangri-La Toronto        Hotel
# 11  Marriott Downtown at CF Toronto Eaton Centre        Hotel
# 12                                Hilton Toronto        Hotel
# 17                                Grand Ballroom  Event Space
#
#                   address        lat        lng postalCode state
# 0   123 Queen Street West  43.651144 -79.384329    M5H 2M9    ON
# 2     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 3          123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 10    188 University Ave.  43.649129 -79.386557    M5H 0A3    ON
# 11         525 Bay Street  43.654728 -79.382422    M5G 2L2    ON
# 12      145 Richmond St W  43.649946 -79.385479    M5H 2L2    ON
# 17        123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON

# %%
# delete rows which has duplicate hotel's name
df_hotels = hotel_dataframe.drop_duplicates(subset='name', keep="first")
df_hotels
# Out:
#                                             name   categories  \
# 0                  Sheraton Centre Toronto Hotel        Hotel
# 2    DoubleTree by Hilton Hotel Toronto Downtown        Hotel
# 3                                 VFM Test Hotel        Hotel
# 10                            Shangri-La Toronto        Hotel
# 11  Marriott Downtown at CF Toronto Eaton Centre        Hotel
# 12                                Hilton Toronto        Hotel
# 17                                Grand Ballroom  Event Space
#
#                   address        lat        lng postalCode state
# 0   123 Queen Street West  43.651144 -79.384329    M5H 2M9    ON
# 2     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 3          123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 10    188 University Ave.  43.649129 -79.386557    M5H 0A3    ON
# 11         525 Bay Street  43.654728 -79.382422    M5G 2L2    ON
# 12      145 Richmond St W  43.649946 -79.385479    M5H 2L2    ON
# 17        123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON

# %%
# choose the hotel which has the same postalCode with the event space
df_hotel = df_hotels[df_hotels.postalCode == 'M5H 2M9']
df_hotel
# Out:
#                              name   categories                address  \
# 0   Sheraton Centre Toronto Hotel        Hotel  123 Queen Street West
# 17                 Grand Ballroom  Event Space        123 Queen St. W
#
#           lat        lng postalCode state
# 0   43.651144 -79.384329    M5H 2M9    ON
# 17  43.651217 -79.383771    M5H 2M9    ON

# %% [markdown]
# ### Search for Parks

# %%
# search for Parks
search_query = 'Park'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=N45O4RRDNKFDENDC3JZ0V40MDEAT3VIAHNND5JEIOHF4UXDY&client_secret=LHTZHTCDSJVJY52N2AELBKK3M401Q1KLQBPAB12KIPAMBOOU&ll=43.653963,-79.387207&v=20180604&query=Park&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
presults = requests.get(url).json()
#presults

# %%
# assign relevant part of JSON to venues
venues = presults['response']['venues']

# tranform venues into a dataframe
park_dataframe = json_normalize(venues)
park_dataframe.head()
# Out:
#                          id                         name  \
# 0  4b170e47f964a5208cc123e3  Queen's Park Subway Station
# 1  4b54deadf964a520a3d027e3                  Grange Park
# 2  4bb79860cf2fc9b616779e02                  Berczy Park
# 3  4ad80fcef964a520a61021e3                One Park Lane
# 4  4b9d206bf964a520e69136e3                 Queen's Park
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fd931735', 'name': 'M...  v-1574476014    False
# 1  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...  v-1574476014    False
# 2  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...  v-1574476014    False
# 3  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1574476014    False
# 4  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...  v-1574476014    False
#
#          location.address location.crossStreet  location.lat  location.lng  \
# 0      691 University Ave        at College St     43.660006    -79.390272
# 1                     NaN                  NaN     43.652488    -79.392053
# 2  35 Wellington St. East                  NaN     43.648048    -79.375172
# 3           280 Simcoe St   Dundas Street West     43.655442    -79.390056
# 4         University Ave.    at Wellesley Ave.     43.663946    -79.392180
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 43.66000635700919...                716
# 1  [{'label': 'display', 'lat': 43.65248755299856...                423
# 2  [{'label': 'display', 'lat': 43.64804835388851...               1171
# 3  [{'label': 'display', 'lat': 43.65544241747622...                282
# 4  [{'label': 'display', 'lat': 43.66394609897775...               1181
#
#   location.postalCode location.cc location.city location.state  \
# 0             M5G 2P1          CA       Toronto             ON
# 1                 NaN          CA       Toronto             ON
# 2                 NaN          CA       Toronto             ON
# 3             M5T 2Y5          CA       Toronto             ON
# 4             M5R 2E8          CA       Toronto             ON
#
#   location.country                          location.formattedAddress  \
# 0           Canada  [691 University Ave (at College St), Toronto O...
# 1           Canada  [btwn College, University, Queen & Spadina, To...
# 2           Canada       [35 Wellington St. East, Toronto ON, Canada]
# 3           Canada  [280 Simcoe St (Dundas Street West), Toronto O...
# 4           Canada  [University Ave. (at Wellesley Ave.), Toronto ...
#
#   venuePage.id
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %% [markdown]
# ### Clean Park Dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
park_clean_columns = ['name', 'categories'] + [col for col in park_dataframe.columns if col.startswith('location.')]+ ['id']
clean_park_dataframe = park_dataframe.loc[:,park_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list1 = row['categories']
    except:
        categories_list1 = row['venue.categories']
        
    if len(categories_list1) == 0:
        return None
    else:
        return categories_list1[0]['name']

# filter the category for each row
clean_park_dataframe['categories'] = clean_park_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_park_dataframe.columns = [column.split('.')[-1] for column in clean_park_dataframe.columns]

clean_park_dataframe.head()
# Out:
#                           name                                categories  \
# 0  Queen's Park Subway Station                             Metro Station
# 1                  Grange Park                                      Park
# 2                  Berczy Park                                      Park
# 3                One Park Lane  Residential Building (Apartment / Condo)
# 4                 Queen's Park                                      Park
#
#                   address         crossStreet        lat        lng  \
# 0      691 University Ave       at College St  43.660006 -79.390272
# 1                     NaN                 NaN  43.652488 -79.392053
# 2  35 Wellington St. East                 NaN  43.648048 -79.375172
# 3           280 Simcoe St  Dundas Street West  43.655442 -79.390056
# 4         University Ave.   at Wellesley Ave.  43.663946 -79.392180
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 43.66000635700919...       716    M5G 2P1  CA
# 1  [{'label': 'display', 'lat': 43.65248755299856...       423        NaN  CA
# 2  [{'label': 'display', 'lat': 43.64804835388851...      1171        NaN  CA
# 3  [{'label': 'display', 'lat': 43.65544241747622...       282    M5T 2Y5  CA
# 4  [{'label': 'display', 'lat': 43.66394609897775...      1181    M5R 2E8  CA
#
#       city state country                                   formattedAddress  \
# 0  Toronto    ON  Canada  [691 University Ave (at College St), Toronto O...
# 1  Toronto    ON  Canada  [btwn College, University, Queen & Spadina, To...
# 2  Toronto    ON  Canada       [35 Wellington St. East, Toronto ON, Canada]
# 3  Toronto    ON  Canada  [280 Simcoe St (Dundas Street West), Toronto O...
# 4  Toronto    ON  Canada  [University Ave. (at Wellesley Ave.), Toronto ...
#
#                          id
# 0  4b170e47f964a5208cc123e3
# 1  4b54deadf964a520a3d027e3
# 2  4bb79860cf2fc9b616779e02
# 3  4ad80fcef964a520a61021e3
# 4  4b9d206bf964a520e69136e3

# %%
# delete unnecessary columns
clean_park_dataframe2= clean_park_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_park_dataframe2
# Out:
#                                        name  \
# 0               Queen's Park Subway Station
# 1                               Grange Park
# 2                               Berczy Park
# 3                             One Park Lane
# 4                              Queen's Park
# 5         St. Andrews Playground / Dog Park
# 6             Crunch Fitness - College Park
# 7          Residences at College Park North
# 8                    Trinity Bellwoods Park
# 9        TTC Streetcar #403 - Victoria park
# 10                     Bellevue Square Park
# 11                     Clarence Square Park
# 12                   Physiomed College Park
# 13                                High Park
# 14                             College Park
# 15  GoodLife Fitness Toronto Bloor and Park
# 16         Toothworks - College Park Dental
# 17                                 HTO Park
# 18                       Canoe Landing Park
# 19                      Riverdale Park West
# 20                  Moss Park Tennis Courts
# 21                      RBC WaterPark Place
# 22                          Coronation Park
# 23                             Stanley Park
# 24                      Riverdale Park East
# 25                  St Lawrence on the Park
# 26                       Battery Park Tower
# 27                        Barbara Hall Park
# 28                        Barbara Hall Park
# 29                   Parliament Square Park
#
#                                   categories                       address  \
# 0                              Metro Station            691 University Ave
# 1                                       Park                           NaN
# 2                                       Park        35 Wellington St. East
# 3   Residential Building (Apartment / Condo)                 280 Simcoe St
# 4                                       Park               University Ave.
# 5                                       Park      450 Adelaide Street West
# 6                       Gym / Fitness Center              382 Yonge Street
# 7   Residential Building (Apartment / Condo)                   763 Bay St.
# 8                                       Park            1053 Dundas St. W.
# 9                         Light Rail Station                           NaN
# 10                                      Park  btwn Bellevue & Augusta Ave.
# 11                                      Park                   Spadina Ave
# 12                            Medical Center                  382 Yonge St
# 13                                      Park              1873 Bloor St. W
# 14                             Shopping Mall                  444 Yonge St
# 15                                       Gym                     8 Park Rd
# 16                          Dentist's Office        444 Yonge St, Unit M16
# 17                                      Park                  Queen's Quay
# 18                                      Park             50 Fort York Blvd
# 19                                      Park               500 Gerrard St.
# 20                              Tennis Court                     Moss Park
# 21                                    Office                88 Queens Quay
# 22                                      Park        711 Lake Shore Blvd. W
# 23                                      Park              King Street West
# 24                                      Park             550 Broadview Ave
# 25                                  Building               65 Scadding Ave
# 26  Residential Building (Apartment / Condo)           50 Lynn Williams St
# 27                                      Park             519 Church Street
# 28                                      Park                 519 Church St
# 29                                      Park          44 Parliament Street
#
#           lat        lng postalCode state
# 0   43.660006 -79.390272    M5G 2P1    ON
# 1   43.652488 -79.392053        NaN    ON
# 2   43.648048 -79.375172        NaN    ON
# 3   43.655442 -79.390056    M5T 2Y5    ON
# 4   43.663946 -79.392180    M5R 2E8    ON
# 5   43.647388 -79.398752        NaN    ON
# 6   43.659263 -79.382632    M5G 1S8    ON
# 7   43.659822 -79.385159    M5G 2R3    ON
# 8   43.647072 -79.413756    M5H 2N2    ON
# 9   43.650735 -79.386921        NaN    ON
# 10  43.653610 -79.402199    M5T 2N4    ON
# 11  43.644222 -79.394230        NaN    ON
# 12  43.659240 -79.382860    M5B 1S8    ON
# 13  43.646479 -79.463425    M6R 2Z3    ON
# 14  43.661237 -79.383603    M5B 2H4    ON
# 15  43.671302 -79.384691    M4W 3G8    ON
# 16  43.660009 -79.383905        NaN    ON
# 17  43.637949 -79.387820        NaN    ON
# 18  43.638762 -79.397067    M5V 3Z1    ON
# 19  43.666048 -79.360941    M5A 2H3    ON
# 20  43.655337 -79.371923        NaN    ON
# 21  43.641075 -79.379154        NaN    ON
# 22  43.634553 -79.405403    M5V 3T7    ON
# 23  43.642395 -79.409330        NaN    ON
# 24  43.669951 -79.355493    M4K 2P1    ON
# 25  43.648963 -79.364868        NaN    ON
# 26  43.639024 -79.415510    M6K 3R9    ON
# 27  43.666728 -79.381084        NaN    ON
# 28  43.666879 -79.381068    M4Y 2K9    ON
# 29  43.650264 -79.362195        NaN    ON

# %%
# delete rows with none values
clean_park_dataframe3 = clean_park_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_park_dataframe3
# Out:
#                                        name  \
# 0               Queen's Park Subway Station
# 3                             One Park Lane
# 4                              Queen's Park
# 6             Crunch Fitness - College Park
# 7          Residences at College Park North
# 8                    Trinity Bellwoods Park
# 10                     Bellevue Square Park
# 12                   Physiomed College Park
# 13                                High Park
# 14                             College Park
# 15  GoodLife Fitness Toronto Bloor and Park
# 18                       Canoe Landing Park
# 19                      Riverdale Park West
# 22                          Coronation Park
# 24                      Riverdale Park East
# 26                       Battery Park Tower
# 28                        Barbara Hall Park
#
#                                   categories                       address  \
# 0                              Metro Station            691 University Ave
# 3   Residential Building (Apartment / Condo)                 280 Simcoe St
# 4                                       Park               University Ave.
# 6                       Gym / Fitness Center              382 Yonge Street
# 7   Residential Building (Apartment / Condo)                   763 Bay St.
# 8                                       Park            1053 Dundas St. W.
# 10                                      Park  btwn Bellevue & Augusta Ave.
# 12                            Medical Center                  382 Yonge St
# 13                                      Park              1873 Bloor St. W
# 14                             Shopping Mall                  444 Yonge St
# 15                                       Gym                     8 Park Rd
# 18                                      Park             50 Fort York Blvd
# 19                                      Park               500 Gerrard St.
# 22                                      Park        711 Lake Shore Blvd. W
# 24                                      Park             550 Broadview Ave
# 26  Residential Building (Apartment / Condo)           50 Lynn Williams St
# 28                                      Park                 519 Church St
#
#           lat        lng postalCode state
# 0   43.660006 -79.390272    M5G 2P1    ON
# 3   43.655442 -79.390056    M5T 2Y5    ON
# 4   43.663946 -79.392180    M5R 2E8    ON
# 6   43.659263 -79.382632    M5G 1S8    ON
# 7   43.659822 -79.385159    M5G 2R3    ON
# 8   43.647072 -79.413756    M5H 2N2    ON
# 10  43.653610 -79.402199    M5T 2N4    ON
# 12  43.659240 -79.382860    M5B 1S8    ON
# 13  43.646479 -79.463425    M6R 2Z3    ON
# 14  43.661237 -79.383603    M5B 2H4    ON
# 15  43.671302 -79.384691    M4W 3G8    ON
# 18  43.638762 -79.397067    M5V 3Z1    ON
# 19  43.666048 -79.360941    M5A 2H3    ON
# 22  43.634553 -79.405403    M5V 3T7    ON
# 24  43.669951 -79.355493    M4K 2P1    ON
# 26  43.639024 -79.415510    M6K 3R9    ON
# 28  43.666879 -79.381068    M4Y 2K9    ON

# %%
# delete rows which its category is not Park
df_park = clean_park_dataframe3[clean_park_dataframe3.categories == 'Park']
df_park
# Out:
#                       name categories                       address  \
# 4             Queen's Park       Park               University Ave.
# 8   Trinity Bellwoods Park       Park            1053 Dundas St. W.
# 10    Bellevue Square Park       Park  btwn Bellevue & Augusta Ave.
# 13               High Park       Park              1873 Bloor St. W
# 18      Canoe Landing Park       Park             50 Fort York Blvd
# 19     Riverdale Park West       Park               500 Gerrard St.
# 22         Coronation Park       Park        711 Lake Shore Blvd. W
# 24     Riverdale Park East       Park             550 Broadview Ave
# 28       Barbara Hall Park       Park                 519 Church St
#
#           lat        lng postalCode state
# 4   43.663946 -79.392180    M5R 2E8    ON
# 8   43.647072 -79.413756    M5H 2N2    ON
# 10  43.653610 -79.402199    M5T 2N4    ON
# 13  43.646479 -79.463425    M6R 2Z3    ON
# 18  43.638762 -79.397067    M5V 3Z1    ON
# 19  43.666048 -79.360941    M5A 2H3    ON
# 22  43.634553 -79.405403    M5V 3T7    ON
# 24  43.669951 -79.355493    M4K 2P1    ON
# 28  43.666879 -79.381068    M4Y 2K9    ON

# %% [markdown]
# ### Search for Restaurants

# %%
# search for Restaurants
search_query = 'Restaurant'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=N45O4RRDNKFDENDC3JZ0V40MDEAT3VIAHNND5JEIOHF4UXDY&client_secret=LHTZHTCDSJVJY52N2AELBKK3M401Q1KLQBPAB12KIPAMBOOU&ll=43.653963,-79.387207&v=20180604&query=Restaurant&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
Rresults = requests.get(url).json()
#Rresults

# %%
# assign relevant part of JSON to venues
venues = Rresults['response']['venues']

# tranform venues into a dataframe
Restaurant_dataframe = json_normalize(venues)
Restaurant_dataframe.head()
# Out:
#                          id                             name  \
# 0  4ad4c05ff964a52048f720e3  Hemispheres Restaurant & Bistro
# 1  4ad4c05cf964a520dff520e3                   360 Restaurant
# 2  4b223f5af964a520ba4424e3           Azure Restaurant & Bar
# 3  4ad4c060f964a5207ff720e3           Rol San Restaurant 龍笙棧
# 4  4ae29812f964a520288f21e3          Swatow Restaurant 汕頭小食家
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...  v-1574476091    False
# 1  [{'id': '4bf58dd8d48988d123941735', 'name': 'W...  v-1574476091    False
# 2  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1574476091    False
# 3  [{'id': '4bf58dd8d48988d1f5931735', 'name': 'D...  v-1574476091    False
# 4  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1574476091    False
#
#       location.address  location.lat  location.lng  \
# 0  110 Chestnut Street     43.654884    -79.385931
# 1       301 Front St W     43.642537    -79.387042
# 2       225 Front St W     43.644749    -79.385113
# 3     323 Spadina Ave.     43.654318    -79.398650
# 4     309 Spadina Ave.     43.653866    -79.398334
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 43.65488413420439...                145
# 1  [{'label': 'display', 'lat': 43.64253731714456...               1271
# 2  [{'label': 'display', 'lat': 43.64474919591934...               1039
# 3  [{'label': 'display', 'lat': 43.65431754076345...                922
# 4  [{'label': 'display', 'lat': 43.65386562507761...                896
#
#   location.postalCode location.cc location.city location.state  \
# 0             M5G 1R3          CA       Toronto             ON
# 1             M5V 2T6          CA       Toronto             ON
# 2             M5V 2X3          CA       Toronto             ON
# 3             M5T 2E9          CA       Toronto             ON
# 4             M5T 2E6          CA       Toronto             ON
#
#   location.country                          location.formattedAddress  \
# 0           Canada  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 1           Canada  [301 Front St W (301 Front St. W), Toronto ON ...
# 2           Canada  [225 Front St W (in InterContinental Toronto C...
# 3           Canada  [323 Spadina Ave. (at D'Arcy St.), Toronto ON ...
# 4           Canada  [309 Spadina Ave. (btwn Dundas St. W & D'Arcy ...
#
#                  location.crossStreet   location.neighborhood venuePage.id
# 0                                 NaN                     NaN          NaN
# 1                     301 Front St. W                     NaN          NaN
# 2  in InterContinental Toronto Centre  Entertainment District    136175835
# 3                       at D'Arcy St.       Kensington Market          NaN
# 4      btwn Dundas St. W & D'Arcy St.                     NaN          NaN

# %% [markdown]
# ### Clean Restaurant Dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
Restaurant_clean_columns = ['name', 'categories'] + [col for col in Restaurant_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Restaurant_dataframe = Restaurant_dataframe.loc[:,Restaurant_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list3 = row['categories']
    except:
        categories_list3 = row['venue.categories']
        
    if len(categories_list3) == 0:
        return None
    else:
        return categories_list3[0]['name']

# filter the category for each row
clean_Restaurant_dataframe['categories'] = clean_Restaurant_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Restaurant_dataframe.columns = [column.split('.')[-1] for column in clean_Restaurant_dataframe.columns]

clean_Restaurant_dataframe.head()
# Out:
#                               name           categories              address  \
# 0  Hemispheres Restaurant & Bistro  American Restaurant  110 Chestnut Street
# 1                   360 Restaurant             Wine Bar       301 Front St W
# 2           Azure Restaurant & Bar           Restaurant       225 Front St W
# 3           Rol San Restaurant 龍笙棧   Dim Sum Restaurant     323 Spadina Ave.
# 4          Swatow Restaurant 汕頭小食家   Chinese Restaurant     309 Spadina Ave.
#
#          lat        lng                                     labeledLatLngs  \
# 0  43.654884 -79.385931  [{'label': 'display', 'lat': 43.65488413420439...
# 1  43.642537 -79.387042  [{'label': 'display', 'lat': 43.64253731714456...
# 2  43.644749 -79.385113  [{'label': 'display', 'lat': 43.64474919591934...
# 3  43.654318 -79.398650  [{'label': 'display', 'lat': 43.65431754076345...
# 4  43.653866 -79.398334  [{'label': 'display', 'lat': 43.65386562507761...
#
#    distance postalCode  cc     city state country  \
# 0       145    M5G 1R3  CA  Toronto    ON  Canada
# 1      1271    M5V 2T6  CA  Toronto    ON  Canada
# 2      1039    M5V 2X3  CA  Toronto    ON  Canada
# 3       922    M5T 2E9  CA  Toronto    ON  Canada
# 4       896    M5T 2E6  CA  Toronto    ON  Canada
#
#                                     formattedAddress  \
# 0  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 1  [301 Front St W (301 Front St. W), Toronto ON ...
# 2  [225 Front St W (in InterContinental Toronto C...
# 3  [323 Spadina Ave. (at D'Arcy St.), Toronto ON ...
# 4  [309 Spadina Ave. (btwn Dundas St. W & D'Arcy ...
#
#                           crossStreet            neighborhood  \
# 0                                 NaN                     NaN
# 1                     301 Front St. W                     NaN
# 2  in InterContinental Toronto Centre  Entertainment District
# 3                       at D'Arcy St.       Kensington Market
# 4      btwn Dundas St. W & D'Arcy St.                     NaN
#
#                          id
# 0  4ad4c05ff964a52048f720e3
# 1  4ad4c05cf964a520dff520e3
# 2  4b223f5af964a520ba4424e3
# 3  4ad4c060f964a5207ff720e3
# 4  4ae29812f964a520288f21e3

# %%
# delete unnecessary columns
clean_Restaurant_dataframe2= clean_Restaurant_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'neighborhood', 'id'], axis=1)
clean_Restaurant_dataframe2
# Out:
#                                               name               categories  \
# 0                  Hemispheres Restaurant & Bistro      American Restaurant
# 1                                   360 Restaurant                 Wine Bar
# 2                           Azure Restaurant & Bar               Restaurant
# 3                           Rol San Restaurant 龍笙棧       Dim Sum Restaurant
# 4                          Swatow Restaurant 汕頭小食家       Chinese Restaurant
# 5                   Goldstone Noodle Restaurant 金石             Noodle House
# 6                            Victoria's Restaurant               Restaurant
# 7               Some Time BBQ Grill Restaurant 碳烤屋      Szechuan Restaurant
# 8                         New Sky Restaurant 小沙田食家       Chinese Restaurant
# 9                   The Hot House Restaurant & Bar      American Restaurant
# 10                         Victor Restaurant & Bar                      Bar
# 11              Sky Dragon Chinese Restaurant 龍翔酒樓       Dim Sum Restaurant
# 12                    Aroma Fine Indian Restaurant        Indian Restaurant
# 13                        Ka Chi Korean Restaurant        Korean Restaurant
# 14         Tasty's Caribbean Restaurant & Catering     Caribbean Restaurant
# 15                   Hong Shing Chinese Restaurant       Chinese Restaurant
# 16              North-East Chinese Restaurant 華北美食       Chinese Restaurant
# 17                   Green Tea Restaurant Downtown       Chinese Restaurant
# 18  Sassafraz | Cafe | Restaurant | Private Events              Event Space
# 19                  Insomnia Restaurant and Lounge               Restaurant
# 20                           ONE Restaurant/Lounge  New American Restaurant
# 21               El Rancho Restaurant & Night Club                Nightclub
# 22                     Woodlot Restaurant & Bakery  New American Restaurant
# 23               Kensington Cornerstone Restaurant           Breakfast Spot
# 24                               Studio Restaurant           Breakfast Spot
# 25                    Yueh Tung Chinese Restaurant       Chinese Restaurant
# 26                 Mapo Korean BBQ Restaurant 마포상회        Korean Restaurant
# 27                                Union Restaurant  New American Restaurant
# 28             Richtree Natural Market Restaurants               Restaurant
# 29                 Kyoto House Japanese Restaurant         Sushi Restaurant
#
#                             address        lat        lng postalCode state
# 0               110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 1                    301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 2                    225 Front St W  43.644749 -79.385113    M5V 2X3    ON
# 3                  323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 4                  309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 5                   266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 6               37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 7                988 Baldwin Street  43.655874 -79.393826        NaN    ON
# 8                  353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 9                      35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 10                 30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 11                 280 Spadina Ave.  43.652783 -79.398174        NaN    ON
# 12                   287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 13                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 14                  405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 15                  195 Dundas St W  43.654925 -79.387089    M5G 1C7    ON
# 16                   476 Dundas St.  43.653185 -79.396677        NaN    ON
# 17  261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 18            100 Cumberland Street  43.670342 -79.391041    M5R 1A6    ON
# 19                563 Bloor St West  43.665180 -79.410966    M5S 1Y6    ON
# 20                116 Yorkville Ave  43.670809 -79.393272        NaN    ON
# 21                  430 College St.  43.656673 -79.407101    M5T 1T3    ON
# 22              293 Palmerston Ave.  43.655765 -79.409929    M6J 2J3    ON
# 23               2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON
# 24                   389 Church St.  43.661500 -79.379319        M5B    ON
# 25                126 Elizabeth St.  43.655281 -79.385337        NaN    ON
# 26                   680 Bloor St W  43.664096 -79.416738    M6G 1L2    ON
# 27                72 Ossington Ave.  43.645860 -79.419532        NaN    ON
# 28                    14 Queen St W  43.652614 -79.380231    M5H 3X4    ON
# 29              143 Dundas St. West  43.655381 -79.385270        NaN    ON

# %%
# delete rows with none values
df_Restaurant = clean_Restaurant_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Restaurant
# Out:
#                                               name               categories  \
# 0                  Hemispheres Restaurant & Bistro      American Restaurant
# 1                                   360 Restaurant                 Wine Bar
# 2                           Azure Restaurant & Bar               Restaurant
# 3                           Rol San Restaurant 龍笙棧       Dim Sum Restaurant
# 4                          Swatow Restaurant 汕頭小食家       Chinese Restaurant
# 5                   Goldstone Noodle Restaurant 金石             Noodle House
# 6                            Victoria's Restaurant               Restaurant
# 8                         New Sky Restaurant 小沙田食家       Chinese Restaurant
# 9                   The Hot House Restaurant & Bar      American Restaurant
# 10                         Victor Restaurant & Bar                      Bar
# 12                    Aroma Fine Indian Restaurant        Indian Restaurant
# 13                        Ka Chi Korean Restaurant        Korean Restaurant
# 14         Tasty's Caribbean Restaurant & Catering     Caribbean Restaurant
# 15                   Hong Shing Chinese Restaurant       Chinese Restaurant
# 17                   Green Tea Restaurant Downtown       Chinese Restaurant
# 18  Sassafraz | Cafe | Restaurant | Private Events              Event Space
# 19                  Insomnia Restaurant and Lounge               Restaurant
# 21               El Rancho Restaurant & Night Club                Nightclub
# 22                     Woodlot Restaurant & Bakery  New American Restaurant
# 23               Kensington Cornerstone Restaurant           Breakfast Spot
# 24                               Studio Restaurant           Breakfast Spot
# 26                 Mapo Korean BBQ Restaurant 마포상회        Korean Restaurant
# 28             Richtree Natural Market Restaurants               Restaurant
#
#                             address        lat        lng postalCode state
# 0               110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 1                    301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 2                    225 Front St W  43.644749 -79.385113    M5V 2X3    ON
# 3                  323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 4                  309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 5                   266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 6               37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 8                  353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 9                      35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 10                 30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 12                   287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 13                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 14                  405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 15                  195 Dundas St W  43.654925 -79.387089    M5G 1C7    ON
# 17  261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 18            100 Cumberland Street  43.670342 -79.391041    M5R 1A6    ON
# 19                563 Bloor St West  43.665180 -79.410966    M5S 1Y6    ON
# 21                  430 College St.  43.656673 -79.407101    M5T 1T3    ON
# 22              293 Palmerston Ave.  43.655765 -79.409929    M6J 2J3    ON
# 23               2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON
# 24                   389 Church St.  43.661500 -79.379319        M5B    ON
# 26                   680 Bloor St W  43.664096 -79.416738    M6G 1L2    ON
# 28                    14 Queen St W  43.652614 -79.380231    M5H 3X4    ON

# %% [markdown]
# ### Search for Cafeteria

# %%
# search for Cafeteria
search_query = 'Cafeteria'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=N45O4RRDNKFDENDC3JZ0V40MDEAT3VIAHNND5JEIOHF4UXDY&client_secret=LHTZHTCDSJVJY52N2AELBKK3M401Q1KLQBPAB12KIPAMBOOU&ll=43.653963,-79.387207&v=20180604&query=Cafeteria&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
cresults = requests.get(url).json()
#cresults

# %%
# assign relevant part of JSON to venues
venues = cresults['response']['venues']

# tranform venues into a dataframe
Cafeteria_dataframe = json_normalize(venues)
Cafeteria_dataframe.head()
# Out:
#                          id                           name  \
# 0  4f9165bde4b04fef0087e4e2                      Cafeteria
# 1  528e99a211d262edc3708a6f              Stay Cafeteria 慢走
# 2  4ec2b68a8231a83de8c45191                 OCAD Cafeteria
# 3  53bd6dfe498e6c1d3bc9333e  Industrial Alliance Cafeteria
# 4  556f826b498e07f469e6bf1f                Dears Cafeteria
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...  v-1574476146    False
# 1  [{'id': '4bf58dd8d48988d142941735', 'name': 'A...  v-1574476146    False
# 2  [{'id': '4bf58dd8d48988d1a1941735', 'name': 'C...  v-1574476146    False
# 3  [{'id': '4bf58dd8d48988d128941735', 'name': 'C...  v-1574476146    False
# 4  [{'id': '4bf58dd8d48988d1d0941735', 'name': 'D...  v-1574476146    False
#
#                             location.address  location.lat  location.lng  \
# 0  The Hospital for Sick Children (SickKids)     43.657209    -79.386063
# 1                            388 Spadina Ave     43.655454    -79.399163
# 2                             100 McCaul St.     43.652780    -79.391762
# 3                                        NaN     43.655657    -79.389443
# 4                                        NaN     43.654179    -79.392555
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 43.65720930549997...                372
# 1  [{'label': 'display', 'lat': 43.65545427446646...                977
# 2  [{'label': 'display', 'lat': 43.65278016892648...                389
# 3  [{'label': 'display', 'lat': 43.655657, 'lng':...                260
# 4  [{'label': 'display', 'lat': 43.65417861938476...                431
#
#   location.cc location.city location.state location.country  \
# 0          CA       Toronto             ON           Canada
# 1          CA       Toronto             ON           Canada
# 2          CA       Toronto             ON           Canada
# 3          CA       Toronto             ON           Canada
# 4          CA           NaN            NaN           Canada
#
#                            location.formattedAddress location.crossStreet  \
# 0  [The Hospital for Sick Children (SickKids), To...                  NaN
# 1  [388 Spadina Ave (at Nassau St), Toronto ON M5...         at Nassau St
# 2  [100 McCaul St. (Second Floor), Toronto ON, Ca...         Second Floor
# 3                               [Toronto ON, Canada]                  NaN
# 4                                           [Canada]                  NaN
#
#   location.postalCode
# 0                 NaN
# 1             M5T 2G5
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %% [markdown]
# ### Clean Cafeteria Dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
Cafeteria_clean_columns = ['name', 'categories'] + [col for col in Cafeteria_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Cafeteria_dataframe = Cafeteria_dataframe.loc[:,Cafeteria_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list4 = row['categories']
    except:
        categories_list4 = row['venue.categories']
        
    if len(categories_list4) == 0:
        return None
    else:
        return categories_list4[0]['name']

# filter the category for each row
clean_Cafeteria_dataframe['categories'] = clean_Cafeteria_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Cafeteria_dataframe.columns = [column.split('.')[-1] for column in clean_Cafeteria_dataframe.columns]

clean_Cafeteria_dataframe.head()
# Out:
#                             name            categories  \
# 0                      Cafeteria  Fast Food Restaurant
# 1              Stay Cafeteria 慢走      Asian Restaurant
# 2                 OCAD Cafeteria     College Cafeteria
# 3  Industrial Alliance Cafeteria             Cafeteria
# 4                Dears Cafeteria          Dessert Shop
#
#                                      address        lat        lng  \
# 0  The Hospital for Sick Children (SickKids)  43.657209 -79.386063
# 1                            388 Spadina Ave  43.655454 -79.399163
# 2                             100 McCaul St.  43.652780 -79.391762
# 3                                        NaN  43.655657 -79.389443
# 4                                        NaN  43.654179 -79.392555
#
#                                       labeledLatLngs  distance  cc     city  \
# 0  [{'label': 'display', 'lat': 43.65720930549997...       372  CA  Toronto
# 1  [{'label': 'display', 'lat': 43.65545427446646...       977  CA  Toronto
# 2  [{'label': 'display', 'lat': 43.65278016892648...       389  CA  Toronto
# 3  [{'label': 'display', 'lat': 43.655657, 'lng':...       260  CA  Toronto
# 4  [{'label': 'display', 'lat': 43.65417861938476...       431  CA      NaN
#
#   state country                                   formattedAddress  \
# 0    ON  Canada  [The Hospital for Sick Children (SickKids), To...
# 1    ON  Canada  [388 Spadina Ave (at Nassau St), Toronto ON M5...
# 2    ON  Canada  [100 McCaul St. (Second Floor), Toronto ON, Ca...
# 3    ON  Canada                               [Toronto ON, Canada]
# 4   NaN  Canada                                           [Canada]
#
#     crossStreet postalCode                        id
# 0           NaN        NaN  4f9165bde4b04fef0087e4e2
# 1  at Nassau St    M5T 2G5  528e99a211d262edc3708a6f
# 2  Second Floor        NaN  4ec2b68a8231a83de8c45191
# 3           NaN        NaN  53bd6dfe498e6c1d3bc9333e
# 4           NaN        NaN  556f826b498e07f469e6bf1f

# %%
# delete unnecessary columns
clean_Cafeteria_dataframe2= clean_Cafeteria_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_Cafeteria_dataframe2
# Out:
#                                      name            categories  \
# 0                               Cafeteria  Fast Food Restaurant
# 1                       Stay Cafeteria 慢走      Asian Restaurant
# 2                          OCAD Cafeteria     College Cafeteria
# 3           Industrial Alliance Cafeteria             Cafeteria
# 4                         Dears Cafeteria          Dessert Shop
# 5                 Chestnut Tree Cafeteria             Cafeteria
# 6                         Sears Cafeteria            Food Court
# 7           De La Salle College Cafeteria     College Cafeteria
# 8                       Med Sci Cafeteria     College Cafeteria
# 9                   Ryerson Hub Cafeteria     College Cafeteria
# 10                     SickKids Cafeteria            Food Court
# 11                      Robarts Cafeteria     College Cafeteria
# 12              Macdonald Block Cafeteria             Cafeteria
# 13  George Brown College St. James Campus     Community College
# 14                          OMP Cafeteria             Cafeteria
# 15                       Rogers Cafeteria            Food Court
# 16                      Choices Cafeteria            Food Court
# 17    Cafeteria, Lawrence Park Collegiate           High School
# 18                       Kasala Cafeteria    African Restaurant
# 19    Cafeteria, Lawrence Park Collegiate           Event Space
# 20               Estonian House Cafeteria                  Café
# 21                             Marketeria            Restaurant
# 22                                The Hub     College Cafeteria
# 23                           CC Cafeteria     College Cafeteria
# 24                             Radio Cafe            Food Court
# 25                          Innis College        Student Center
# 26     Lawrence Park Collegiate Cafeteria           High School
# 27                           L5 Cafeteria      Cuban Restaurant
# 28                      Glendon Cafeteria     College Cafeteria
# 29  6th Floor Cafeteria 12 Concorde Place                  Café
#
#                                       address        lat        lng state  \
# 0   The Hospital for Sick Children (SickKids)  43.657209 -79.386063    ON
# 1                             388 Spadina Ave  43.655454 -79.399163    ON
# 2                              100 McCaul St.  43.652780 -79.391762    ON
# 3                                         NaN  43.655657 -79.389443    ON
# 4                                         NaN  43.654179 -79.392555   NaN
# 5                          89 Chestnut Street  43.648231 -79.384045    ON
# 6                                       Yonge  43.656038 -79.380672    ON
# 7                          131 Farnham Avenue  43.683003 -79.397815    ON
# 8                                         NaN  43.660260 -79.392977    ON
# 9                            350 Victoria St.  43.658475 -79.377653    ON
# 10                      555 University Avenue  43.657584 -79.375652    ON
# 11                         130 St. George St.  43.664864 -79.399766    ON
# 12                                        NaN  43.663212 -79.388062   NaN
# 13                          200 King St. East  43.651366 -79.370158    ON
# 14                           1 Mount Pleasant  43.669801 -79.379790    ON
# 15                                        NaN  43.669904 -79.379748    ON
# 16                         200 Bloor Street E  43.671411 -79.381849    ON
# 17                                        NaN  43.721732 -79.409600   NaN
# 18                                      Bloor  43.660759 -79.424018   NaN
# 19                                        NaN  43.723286 -79.412222   NaN
# 20                       958 Broadview avenue  43.681763 -79.358246    ON
# 21                                30 Bond St.  43.653585 -79.378843    ON
# 22                           350 Victoria St.  43.658585 -79.380622    ON
# 23                             951 Carlaw Ave  43.684631 -79.348862    ON
# 24                          333 Bloor st east  43.671696 -79.380617    ON
# 25                               2 Sussex Ave  43.665556 -79.399298    ON
# 26                                        NaN  43.722757 -79.413734    ON
# 27                                        NaN  43.723019 -79.345012   NaN
# 28                           2275 Bayview Ave  43.727383 -79.378080    ON
# 29                          12 Concorde Place  43.721861 -79.329339    ON
#
#    postalCode
# 0         NaN
# 1     M5T 2G5
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7     M4V 1H7
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21    M5B 1W8
# 22    M5B 2K3
# 23        NaN
# 24        NaN
# 25    M5S 1J5
# 26        NaN
# 27        NaN
# 28        NaN
# 29    m3c 3k7

# %%
# delete rows with none values
df_Cafeteria = clean_Cafeteria_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Cafeteria
# Out:
#                                      name         categories  \
# 1                       Stay Cafeteria 慢走   Asian Restaurant
# 7           De La Salle College Cafeteria  College Cafeteria
# 21                             Marketeria         Restaurant
# 22                                The Hub  College Cafeteria
# 25                          Innis College     Student Center
# 29  6th Floor Cafeteria 12 Concorde Place               Café
#
#                address        lat        lng state postalCode
# 1      388 Spadina Ave  43.655454 -79.399163    ON    M5T 2G5
# 7   131 Farnham Avenue  43.683003 -79.397815    ON    M4V 1H7
# 21         30 Bond St.  43.653585 -79.378843    ON    M5B 1W8
# 22    350 Victoria St.  43.658585 -79.380622    ON    M5B 2K3
# 25        2 Sussex Ave  43.665556 -79.399298    ON    M5S 1J5
# 29   12 Concorde Place  43.721861 -79.329339    ON    m3c 3k7

# %% [markdown]
# ### Search for Shopping Stores

# %%
# search for Shopping
search_query = 'Shopping'
radius = 1000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=N45O4RRDNKFDENDC3JZ0V40MDEAT3VIAHNND5JEIOHF4UXDY&client_secret=LHTZHTCDSJVJY52N2AELBKK3M401Q1KLQBPAB12KIPAMBOOU&ll=43.653963,-79.387207&v=20180604&query=Shopping&radius=1000&limit=30'

# %%
# Send the GET Request and examine the results
sresults = requests.get(url).json()
#sresults

# %%
# assign relevant part of JSON to venues
venues = sresults['response']['venues']

# tranform venues into a dataframe
Shopping_dataframe = json_normalize(venues)
Shopping_dataframe.head()
# Out:
#                          id                                        name  \
# 0  4ad4c062f964a520fcf720e3                Dragon City Shopping Mall 龍城
# 1  4ad77a12f964a520260b21e3                     CF Toronto Eaton Centre
# 2  4b9e86dff964a520e6eb36e3                TD Centre Shopping Concourse
# 3  5840cafe06f1a34af80cc609  Saks Fifth Avenue Club - Personal Shopping
# 4  4b83d653f964a520d91231e3             Yellow Pages - RedFlagDeals.com
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...  v-1574476846    False
# 1  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...  v-1574476846    False
# 2  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...  v-1574476846    False
# 3  [{'id': '4bf58dd8d48988d1f6941735', 'name': 'D...  v-1574476846    False
# 4  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...  v-1574476846    False
#
#      location.address location.crossStreet  location.lat  location.lng  \
# 0     280 Spadina Ave       at Dundas St W     43.652774    -79.398222
# 1        220 Yonge St  btwn Queen & Dundas     43.653594    -79.380611
# 2  66 Wellington St W    btw York & Bay St     43.647184    -79.380932
# 3    176 Yonge Street    Queen Street West     43.651810    -79.379192
# 4   461 King St. West                  NaN     43.647958    -79.396006
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 43.65277367198862...                897
# 1                                                NaN                532
# 2  [{'label': 'display', 'lat': 43.64718424611984...                908
# 3  [{'label': 'display', 'lat': 43.65181, 'lng': ...                688
# 4  [{'label': 'display', 'lat': 43.64795765580337...                974
#
#   location.postalCode location.cc location.city location.state  \
# 0             M5T 3A5          CA       Toronto             ON
# 1             M5B 2H1          CA       Toronto             ON
# 2             M5K 1A1          CA       Toronto             ON
# 3             M5C 2L7          CA       Toronto             ON
# 4             M5V 1K4          CA       Toronto             ON
#
#   location.country                          location.formattedAddress  \
# 0           Canada  [280 Spadina Ave (at Dundas St W), Toronto ON ...
# 1           Canada  [220 Yonge St (btwn Queen & Dundas), Toronto O...
# 2           Canada  [66 Wellington St W (btw York & Bay St), Toron...
# 3           Canada  [176 Yonge Street (Queen Street West), Toronto...
# 4           Canada    [461 King St. West, Toronto ON M5V 1K4, Canada]
#
#            location.neighborhood
# 0                            NaN
# 1  Downtown Toronto, Toronto, ON
# 2                            NaN
# 3                            NaN
# 4                            NaN

# %% [markdown]
# ### Clean Shopping Dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
Shopping_clean_columns = ['name', 'categories'] + [col for col in Shopping_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Shopping_dataframe = Shopping_dataframe.loc[:,Shopping_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list5 = row['categories']
    except:
        categories_list5 = row['venue.categories']
        
    if len(categories_list5) == 0:
        return None
    else:
        return categories_list5[0]['name']

# filter the category for each row
clean_Shopping_dataframe['categories'] = clean_Shopping_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Shopping_dataframe.columns = [column.split('.')[-1] for column in clean_Shopping_dataframe.columns]

clean_Shopping_dataframe.head()
# Out:
#                                          name        categories  \
# 0                Dragon City Shopping Mall 龍城     Shopping Mall
# 1                     CF Toronto Eaton Centre     Shopping Mall
# 2                TD Centre Shopping Concourse     Shopping Mall
# 3  Saks Fifth Avenue Club - Personal Shopping  Department Store
# 4             Yellow Pages - RedFlagDeals.com            Office
#
#               address          crossStreet        lat        lng  \
# 0     280 Spadina Ave       at Dundas St W  43.652774 -79.398222
# 1        220 Yonge St  btwn Queen & Dundas  43.653594 -79.380611
# 2  66 Wellington St W    btw York & Bay St  43.647184 -79.380932
# 3    176 Yonge Street    Queen Street West  43.651810 -79.379192
# 4   461 King St. West                  NaN  43.647958 -79.396006
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 43.65277367198862...       897    M5T 3A5  CA
# 1                                                NaN       532    M5B 2H1  CA
# 2  [{'label': 'display', 'lat': 43.64718424611984...       908    M5K 1A1  CA
# 3  [{'label': 'display', 'lat': 43.65181, 'lng': ...       688    M5C 2L7  CA
# 4  [{'label': 'display', 'lat': 43.64795765580337...       974    M5V 1K4  CA
#
#       city state country                                   formattedAddress  \
# 0  Toronto    ON  Canada  [280 Spadina Ave (at Dundas St W), Toronto ON ...
# 1  Toronto    ON  Canada  [220 Yonge St (btwn Queen & Dundas), Toronto O...
# 2  Toronto    ON  Canada  [66 Wellington St W (btw York & Bay St), Toron...
# 3  Toronto    ON  Canada  [176 Yonge Street (Queen Street West), Toronto...
# 4  Toronto    ON  Canada    [461 King St. West, Toronto ON M5V 1K4, Canada]
#
#                     neighborhood                        id
# 0                            NaN  4ad4c062f964a520fcf720e3
# 1  Downtown Toronto, Toronto, ON  4ad77a12f964a520260b21e3
# 2                            NaN  4b9e86dff964a520e6eb36e3
# 3                            NaN  5840cafe06f1a34af80cc609
# 4                            NaN  4b83d653f964a520d91231e3

# %%
# delete unnecessary columns
clean_Shopping_dataframe2= clean_Shopping_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'neighborhood', 'id'], axis=1)
clean_Shopping_dataframe2
# Out:
#                                          name        categories  \
# 0                Dragon City Shopping Mall 龍城     Shopping Mall
# 1                     CF Toronto Eaton Centre     Shopping Mall
# 2                TD Centre Shopping Concourse     Shopping Mall
# 3  Saks Fifth Avenue Club - Personal Shopping  Department Store
# 4             Yellow Pages - RedFlagDeals.com            Office
#
#               address        lat        lng postalCode state
# 0     280 Spadina Ave  43.652774 -79.398222    M5T 3A5    ON
# 1        220 Yonge St  43.653594 -79.380611    M5B 2H1    ON
# 2  66 Wellington St W  43.647184 -79.380932    M5K 1A1    ON
# 3    176 Yonge Street  43.651810 -79.379192    M5C 2L7    ON
# 4   461 King St. West  43.647958 -79.396006    M5V 1K4    ON

# %%
# delete rows which its category is not Shopping Mall
df_Shopping = clean_Shopping_dataframe2[clean_Shopping_dataframe2.categories == 'Shopping Mall']
df_Shopping
# Out:
#                            name     categories             address        lat  \
# 0  Dragon City Shopping Mall 龍城  Shopping Mall     280 Spadina Ave  43.652774
# 1       CF Toronto Eaton Centre  Shopping Mall        220 Yonge St  43.653594
# 2  TD Centre Shopping Concourse  Shopping Mall  66 Wellington St W  43.647184
#
#          lng postalCode state
# 0 -79.398222    M5T 3A5    ON
# 1 -79.380611    M5B 2H1    ON
# 2 -79.380932    M5K 1A1    ON

# %% [markdown]
# ### Generate map to visualize hotels, shopping stores and Cafeteria and how they cluster together

# %%
# create dataframe of hotels, shopping stores and Cafeteria
hotel_neighbourhood_df = pd.concat([df_hotel, df_Cafeteria, df_Shopping], ignore_index=True, sort=True)
hotel_neighbourhood_df
# Out:
#                   address         categories        lat        lng  \
# 0   123 Queen Street West              Hotel  43.651144 -79.384329
# 1         123 Queen St. W        Event Space  43.651217 -79.383771
# 2         388 Spadina Ave   Asian Restaurant  43.655454 -79.399163
# 3      131 Farnham Avenue  College Cafeteria  43.683003 -79.397815
# 4             30 Bond St.         Restaurant  43.653585 -79.378843
# 5        350 Victoria St.  College Cafeteria  43.658585 -79.380622
# 6            2 Sussex Ave     Student Center  43.665556 -79.399298
# 7       12 Concorde Place               Café  43.721861 -79.329339
# 8         280 Spadina Ave      Shopping Mall  43.652774 -79.398222
# 9            220 Yonge St      Shopping Mall  43.653594 -79.380611
# 10     66 Wellington St W      Shopping Mall  43.647184 -79.380932
#
#                                      name postalCode state
# 0           Sheraton Centre Toronto Hotel    M5H 2M9    ON
# 1                          Grand Ballroom    M5H 2M9    ON
# 2                       Stay Cafeteria 慢走    M5T 2G5    ON
# 3           De La Salle College Cafeteria    M4V 1H7    ON
# 4                              Marketeria    M5B 1W8    ON
# 5                                 The Hub    M5B 2K3    ON
# 6                           Innis College    M5S 1J5    ON
# 7   6th Floor Cafeteria 12 Concorde Place    m3c 3k7    ON
# 8            Dragon City Shopping Mall 龍城    M5T 3A5    ON
# 9                 CF Toronto Eaton Centre    M5B 2H1    ON
# 10           TD Centre Shopping Concourse    M5K 1A1    ON

# %%
# Generate map to visualize hotel neighbourhood including shopping stores and Cafeteria 
hotel_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(hotel_neighbourhood_df['lat'], hotel_neighbourhood_df['lng'], 
                                           hotel_neighbourhood_df['name'], hotel_neighbourhood_df['categories'],\
                                               hotel_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(hotel_map)  
    
hotel_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Generate map to visualize Park, Restaurant and Cafeteria and how they cluster together

# %%
# create dataframe of Park, Restaurant and Cafeteria
park_neighbourhood_df = pd.concat([df_park, df_Restaurant, df_Cafeteria,], ignore_index=True)
park_neighbourhood_df

# %%
# Generate map to visualize park neighbourhood including Restaurant and Cafeteria 
park_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(park_neighbourhood_df['lat'], park_neighbourhood_df['lng'], 
                                           park_neighbourhood_df['name'], park_neighbourhood_df['categories'],\
                                               park_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(park_map)  
    
park_map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-de8e82e5f8e9> in <module>
#       2 park_map = folium.Map(location=[latitude, longitude], zoom_start=14)
#       3
# ----> 4 for lat, lng, name, categories, address in zip(park_neighbourhood_df['lat'], park_neighbourhood_df['lng'],
#       5                                            park_neighbourhood_df['name'], park_neighbourhood_df['categories'],\
#       6                                                park_neighbourhood_df['address']):
#
# NameError: name 'park_neighbourhood_df' is not defined
